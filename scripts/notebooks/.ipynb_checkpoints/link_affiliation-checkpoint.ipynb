# %% [markdown]
# # Linking Affiliation with Network Data
#
# In this notebook I want to start linking the universities/departments that appear in the network dataset to their affiliation ID that appears in the MAG dataset. There are few enough universities that where there are not exact matches on the basis of the name of the school, that I can do a little bit of work to manually find the appropriate ID.
#
# But first, I will try to make it easy for myself and normalize the university name and do a one to one match on the normalized name, see what proportion of schools I have and the proceed from there.
#
# Ultimately, this will be helpful because we will do a direct link from the network dataset and the MAG dataset by matching the authors name (direct matches only) and their most recent affiliation. Hopefully that will get us a more accurate look at the citations and publication counts for everyone.

# %%
import os
import re
import csv
import glob
import json
import functions
import pandas as pd
import dask.dataframe as dd

os.chdir('/home/timothyelder/mag')

path = '/project/jevans/MAG_0802_2021_snap_shot/'

# read in the normalized faculty names from the network data
with open("data/faculty_names.txt", "r") as f:
    faculty_names = json.loads(f.read())

faculty_df_complete = pd.read_csv('data/faculty_df_complete.csv')
faculty_df_complete = faculty_df_complete[faculty_df_complete["year_observed"] >= 2020] # subset to just 2020-21 observations

departments = set(faculty_df_complete['current_dept'].to_list())
departments = list(departments)

# %%
dept_df = faculty_df_complete.groupby(['current_dept']).size().reset_index(name='counts')
dept_df["pct"] = (dept_df.counts / dept_df.counts.sum())*100
dept_df.sort_values(by=['pct'], ascending=False)

#dept_df[dept_df["current_dept"] == "University of Maryland"]
# Out:
#                                 current_dept  counts       pct
# 89      University of California-Los Angeles      75  1.427756
# 24          Florida International University      74  1.408719
# 88           University of California-Irvine      73  1.389682
# 131  University of North Carolina-Greensboro      71  1.351609
# 156                            Virginia Tech      64  1.218351
# ..                                       ...     ...       ...
# 119                University of Mississippi       9  0.171331
# 143               University of Texas-Dallas       8  0.152294
# 68   Southern Illinois University-Carbondale       7  0.133257
# 138              University of South Alabama       6  0.114220
# 153                Valdosta State University       5  0.095184
#
# [164 rows x 3 columns]

# %% [markdown]
# ## Normalizing Department Names

# %%
for idx, i in enumerate(departments):
    i = i.lower()
    i = re.sub(',|\.', '', i)
    i = re.sub('-', ' ', i)
    i = re.sub('\'', ' ', i)
    i = re.sub('\&', ' ', i)
    
    i = i.strip()
    departments[idx] = i
    
len(set(departments))
# Out:
# 164

# %% [markdown]
# ### Load MAG Affiliations and direct match

# %%
affiliations_df = dd.read_csv(path + 'Affiliations.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['AffiliationId', 'Rank', 'NormalizedName', 'DisplayName',
               'GridId', 'OfficialPage', 'WikiPage', 'PaperCount', 
               'PaperFamilyCount', 'CitationCount', 'Iso3166Code', 'Latitude', 
               'Longitude', 'CreatedDate']

affiliations_df = affiliations_df.rename(columns=dict(zip(affiliations_df.columns, new_columns)))

mag_departments = affiliations_df[affiliations_df['NormalizedName'].isin(set(departments))].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:737: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   **kwargs,
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,

# %%
len(mag_departments)/len(departments) # 93.9% is not too shabby
# Out:
# 0.9390243902439024

# %%
mag_departments.head()
# Out:
#       AffiliationId  Rank                              NormalizedName  \
# 711       114395901  7179              university of nebraska lincoln
# 714       121847817  9794                    the graduate center cuny
# 917       110378019  8472     southern illinois university carbondale
# 928       157725225  5687  university of illinois at urbana champaign
# 1116      149910238  8372                       kent state university
#
#                                      DisplayName         GridId  \
# 711               University of Nebraska–Lincoln  grid.24434.35
# 714                    The Graduate Center, CUNY  grid.253482.a
# 917      Southern Illinois University Carbondale  grid.263856.c
# 928   University of Illinois at Urbana–Champaign  grid.35403.31
# 1116                       Kent State University  grid.258518.3
#
#                   OfficialPage  \
# 711        http://www.unl.edu/
# 714    http://www.gc.cuny.edu/
# 917        http://www.siu.edu/
# 928   http://www.illinois.edu/
# 1116      http://www.kent.edu/
#
#                                                WikiPage  PaperCount  \
# 711   http://en.wikipedia.org/wiki/University_of_Neb...       66965
# 714   http://en.wikipedia.org/wiki/Graduate_Center,_...        6964
# 917   http://en.wikipedia.org/wiki/Southern_Illinois...       27118
# 928   http://en.wikipedia.org/wiki/University_of_Ill...      239875
# 1116  http://en.wikipedia.org/wiki/Kent_State_Univer...       27178
#
#       PaperFamilyCount  CitationCount Iso3166Code   Latitude  Longitude  \
# 711              65385        1739822          US  40.817500  -96.70139
# 714               6619         131006          US  40.748330  -73.98333
# 917              26721         542894          US  37.710426  -89.21931
# 928             229505        8303046          US  40.110540  -88.22841
# 1116             26568         564292          US  41.146410  -81.34174
#
#      CreatedDate
# 711   2016-06-24
# 714   2016-06-24
# 917   2016-06-24
# 928   2016-06-24
# 1116  2016-06-24

# %% [markdown]
# Lets check which departments did not get matched

# %%
no_match = []
for dept in departments:
    if dept not in mag_departments.NormalizedName.to_list():
        no_match.append(dept)
print(len(no_match))
print(set(no_match))
# Out:
# 11
# {'state university of new york buffalo', 'university of illinois chicago', 'university of north carolina chapel hill', 'city university of new york queens college', 'university of alabama birmingham', 'state university of new york albany', 'university of texas el paso', 'university of texas dallas', 'university of north carolina greensboro', 'university of maryland', 'oklahoma state university'}

# %% [markdown]
# ### Manually Finding the no matched departments

# %%
# affiliations_df[affiliations_df['NormalizedName'].str.contains('of maryland')].compute()

# %% [markdown]
# # Merging Dataframes and Matching with MAG to get Authors
#
# ### Normalizing faculty names

# %%
pattern = r'(.+\,)(.+)' # regex for matching the first name and last name
aux_pattern = '(\S+)(.+)' # extra pattern for when the above doesn't match

faculty_df_complete = pd.read_csv("/home/timothyelder/mag/data/faculty_df_complete.csv")
faculty_names = faculty_df_complete['faculty_name'].to_list()

for idx,i in enumerate(faculty_names):
    i = re.sub(r';|:', ',', i)
    # match regex to the file_name string
    if re.search(pattern, i) == None:
        match = re.search(aux_pattern, i)
        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()

        faculty_names[idx] = new_name

    else:
        # match regex to the file_name string
        match = re.search(pattern, i)

        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()
        
        faculty_names[idx] = new_name

faculty_df_complete["faculty_name"] = faculty_names

# %%
faculty_df_complete = faculty_df_complete.rename(columns={"current_dept": "NormalizedName"})

# %%
departments = faculty_df_complete.NormalizedName.to_list()
for idx, i in enumerate(departments):
    i = i.lower()
    i = re.sub(',|\.', '', i)
    i = re.sub('-', ' ', i)
    i = i.strip()
    departments[idx] = i
    
faculty_df_complete["NormalizedName"] = departments

# %%
faculty_df_complete = faculty_df_complete.merge(mag_departments, how='left', on="NormalizedName")
faculty_df_complete.head()
# Out:
#             faculty_name       NormalizedName             source_dept  \
# 0          michael bader  american university  University of Michigan
# 1      monica biradavolu  american university         Duke University
# 2      kim m blankenship  american university         Duke University
# 3  andrea malkin brenner  american university     American University
# 4              alan dahl  american university  University of Kentucky
#
#   phd_year highest_degree                                          interests  \
# 0     2009            PhD                 ['Demography', ' Urban Sociology']
# 1     2005            PhD                ['', ' Global Health', ' HIV/AIDS']
# 2     None            PhD  ['Applied Sociology/Evaluation Research', ' Po...
# 3     None            PhD              ['Family', ' Sociology of Education']
# 4     2010            PhD     ['Comparative Sociology/Historical Sociology']
#
#                        position  year_observed  AffiliationId    Rank  ...  \
# 0           Assistant Professor           2012    181401687.0  8973.0  ...
# 1  Research Assistant Professor           2012    181401687.0  8973.0  ...
# 2              Professor, Chair           2012    181401687.0  8973.0  ...
# 3           Assistant Professor           2012    181401687.0  8973.0  ...
# 4         Professorial Lecturer           2012    181401687.0  8973.0  ...
#
#           GridId              OfficialPage  \
# 0  grid.63124.32  http://www.american.edu/
# 1  grid.63124.32  http://www.american.edu/
# 2  grid.63124.32  http://www.american.edu/
# 3  grid.63124.32  http://www.american.edu/
# 4  grid.63124.32  http://www.american.edu/
#
#                                            WikiPage PaperCount  \
# 0  http://en.wikipedia.org/wiki/American_University    16115.0
# 1  http://en.wikipedia.org/wiki/American_University    16115.0
# 2  http://en.wikipedia.org/wiki/American_University    16115.0
# 3  http://en.wikipedia.org/wiki/American_University    16115.0
# 4  http://en.wikipedia.org/wiki/American_University    16115.0
#
#    PaperFamilyCount  CitationCount  Iso3166Code   Latitude  Longitude  \
# 0           15529.0       274124.0           US  38.937054  -77.08692
# 1           15529.0       274124.0           US  38.937054  -77.08692
# 2           15529.0       274124.0           US  38.937054  -77.08692
# 3           15529.0       274124.0           US  38.937054  -77.08692
# 4           15529.0       274124.0           US  38.937054  -77.08692
#
#    CreatedDate
# 0   2016-06-24
# 1   2016-06-24
# 2   2016-06-24
# 3   2016-06-24
# 4   2016-06-24
#
# [5 rows x 21 columns]

# %%
# Load authors dataframe from MAG
authors_df = dd.read_csv(path + 'Authors.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['AuthorId', 'Rank',
               'NormalizedName', 'DisplayName',
               'LastKnownAffiliationId', 'PaperCount',
               'PaperFamilyCount', 'CitationCount', 'CreatedDate']

authors_df = authors_df.rename(columns=dict(zip(authors_df.columns, new_columns)))
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:737: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   **kwargs,

# %%
# Filter authors dataframe for authors that appear in network data.
filtered_authors = authors_df[authors_df['NormalizedName'].isin(faculty_df_complete.faculty_name)].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,

# %%
print(len(filtered_authors))
print(filtered_authors.head())
# Out:
# 339359
#       AuthorId   Rank     NormalizedName         DisplayName  \
# 471     184369  15782    charles kurzman     Charles Kurzman
# 736     284723  16745   charles n halaby   Charles N. Halaby
# 1602    633513  16244   karen a hegtvedt   Karen A. Hegtvedt
# 4756   2033759  18047  georgi derluguian   Georgi Derluguian
# 6408   2828213  18740  albert j bergesen  Albert J. Bergesen
#
#       LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 471              114027177.0          79                79           1497
# 736              135310074.0           9                 9           1029
# 1602             150468666.0          48                48           1392
# 4756             111979921.0          16                16             71
# 6408                     NaN          11                11             11
#
#      CreatedDate
# 471   2016-06-24
# 736   2016-06-24
# 1602  2016-06-24
# 4756  2016-06-24
# 6408  2016-06-24

# %%
filtered_authors.columns
# Out:
# Index(['AuthorId', 'Rank', 'NormalizedName', 'DisplayName',
#        'LastKnownAffiliationId', 'PaperCount', 'PaperFamilyCount',
#        'CitationCount', 'CreatedDate'],
#       dtype='object')

# %% [markdown]
# ## Renaming Columns and Merging
#
# What I want is to match names and their current affiliation Id

# %%
new_columns = ['NormalizedName', 'current_dept', 'source_dept', 'phd_year',
       'highest_degree', 'interests', 'position', 'year_observed',
       'LastKnownAffiliationId', 'Rank', 'DisplayName', 'GridId',
       'OfficialPage', 'WikiPage', 'PaperCount', 'PaperFamilyCount',
       'CitationCount', 'Iso3166Code', 'Latitude', 'Longitude', 'CreatedDate']

faculty_df_complete = faculty_df_complete.rename(columns=dict(zip(faculty_df_complete.columns, new_columns)))

# %%
df = pd.merge(faculty_df_complete, filtered_authors,  on=['NormalizedName', 'LastKnownAffiliationId'], how = "left", copy=False)
#len(set(df.AuthorId.to_list()))
df = df.dropna()
len(set(df.NormalizedName.to_list()))
# Out:
# 2182

# %%
newest_df = filtered_authors[filtered_authors["LastKnownAffiliationId"].isin(mag_departments.AffiliationId)]

# %%
newest_df[newest_df["NormalizedName"].str.contains('raudenbush')]
# Out:
# Empty DataFrame
# Columns: [AuthorId, Rank, NormalizedName, DisplayName, LastKnownAffiliationId, PaperCount, PaperFamilyCount, CitationCount, CreatedDate]
# Index: []

# %%
len(set(newest_df.NormalizedName.to_list()))/len(set(faculty_df_complete.faculty_name.to_list()))
# Out:
# 0.4775238573581115

# %%
newest_df
# Out:
#           AuthorId   Rank      NormalizedName         DisplayName  \
# 736         284723  16745    charles n halaby   Charles N. Halaby
# 1602        633513  16244    karen a hegtvedt   Karen A. Hegtvedt
# 4756       2033759  18047   georgi derluguian   Georgi Derluguian
# 15293      6937523  18139      sharon koppman      Sharon Koppman
# 16702      7643552  18154  gordana rabrenovic  Gordana Rabrenovic
# ...            ...    ...                 ...                 ...
# 821058  3186645146  19175    jukka savolainen    Jukka Savolainen
# 833894  3186675539  20486     jenifer bratter     Jenifer Bratter
# 855224  3186726551  20463          geoff ward          Geoff Ward
# 909291  3186854906  18517        omer r galle       Omer R. Galle
# 927882  3186899265  20504         victor chen         Victor Chen
#
#         LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 736                135310074.0           9                 9           1029
# 1602               150468666.0          48                48           1392
# 4756               111979921.0          16                16             71
# 15293              204250578.0          17                17             92
# 16702               12912129.0          12                12            113
# ...                        ...         ...               ...            ...
# 821058             185443292.0           7                 7             14
# 833894             143302722.0           2                 2              1
# 855224              12912129.0           2                 2              2
# 909291             200719446.0           4                 4             59
# 927882             921990950.0           2                 2              0
#
#        CreatedDate
# 736     2016-06-24
# 1602    2016-06-24
# 4756    2016-06-24
# 15293   2016-06-24
# 16702   2016-06-24
# ...            ...
# 821058  2021-08-02
# 833894  2021-08-02
# 855224  2021-08-02
# 909291  2021-08-02
# 927882  2021-08-02
#
# [9474 rows x 9 columns]

# %%
mag_departments[mag_departments["AffiliationId"] == 32971472]
# Out:
#       AffiliationId  Rank   NormalizedName      DisplayName         GridId  \
# 8104       32971472  5515  yale university  Yale University  grid.47100.32
#
#               OfficialPage                                      WikiPage  \
# 8104  http://www.yale.edu/  http://en.wikipedia.org/wiki/Yale_University
#
#       PaperCount  PaperFamilyCount  CitationCount Iso3166Code  Latitude  \
# 8104      236418            227650       10778674          US  41.31111
#
#       Longitude CreatedDate
# 8104  -72.92667  2016-06-24

# %% [markdown]
# # Loading the Fuzzy Matches Dataframes

# %%
# concatenating individual matched dataframes
match_path = r'/home/timothyelder/matches'
all_files = glob.glob(match_path + "/*.csv")
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files) # generate a list of files to concatenate

df_merged = pd.concat(df_from_each_file, ignore_index=True) # Concatenate pandas dataframes

names = df_merged['network_name'].to_list()

for idx, i in enumerate(names):
    i = re.sub('\.','', i)
    names[idx] = i

df_merged['network_name'] = names


candidate_matches = df_merged[df_merged['network_name'] == df_merged['NormalizedName']]
df_merged = df_merged[df_merged['network_name'] != df_merged['NormalizedName']]
df_merged = df_merged[df_merged['best_match_score'] >= .50]
candidate_matches = candidate_matches.append(df_merged)
len(candidate_matches)
# Out:
# 95687

# %%
len(df_merged)
print(df_merged.best_match_score.std())
df_merged.best_match_score.min()
df_merged.best_match_score.max()
df_merged.best_match_score.hist(bins=1000)
# Out:
# 0.08654107423431204
# <AxesSubplot:>

# %%
candidate_matches
# Out:
#          Unnamed: 0  best_match_score   __id_left     __id_right  \
# 65             2990          0.659706     74_left  1571423_right
# 295           13260          0.712993    325_left   821791_right
# 302           13550          0.605695    332_left   310220_right
# 308           13798          0.712993    338_left   821791_right
# 343           15578          0.712993    378_left   821791_right
# ...             ...               ...         ...            ...
# 2147649      881333          0.606326  24418_left  2389126_right
# 2147658      881688          0.537550  24427_left  2860951_right
# 2147763      885551          0.593478  24535_left   542508_right
# 2147787      886677          0.593478  24561_left   542508_right
# 2148138      899781          0.605139  24925_left     6685_right
#
#                  faculty_name        network_name      AuthorId  \
# 65        Blankenship, Kim M.   kim m blankenship  3.048999e+09
# 295         Pfohl, Stephen J.     stephen j pfohl  3.045411e+09
# 302           Smith, David H.       david h smith  3.043000e+09
# 308         Pfohl, Stephen J.     stephen j pfohl  3.045411e+09
# 343         Pfohl, Stephen J.     stephen j pfohl  3.045411e+09
# ...                       ...                 ...           ...
# 2147649   Hartwell, Stephanie  stephanie hartwell  3.068725e+09
# 2147658  Dillaway, Heather E.  heather e dillaway  3.069277e+09
# 2147763       Gee, Richard L.       richard l gee  3.066568e+09
# 2147787       Gee, Richard L.       richard l gee  3.066568e+09
# 2148138      Richardson, John     john richardson  3.065943e+09
#
#                  NormalizedName
# 65            kim m blankenship
# 295             stephen j pfohl
# 302               david h smith
# 308             stephen j pfohl
# 343             stephen j pfohl
# ...                         ...
# 2147649    stephanie w hartwell
# 2147658            heather dell
# 2147763             j l richard
# 2147787             j l richard
# 2148138  robert richardson john
#
# [95687 rows x 8 columns]

# %%
#df_merged = df_merged[df_merged['best_match_score'] >= .50]
len(set(candidate_matches.AuthorId))
# Out:
# 30512

# %%
# Filter authors dataframe for authors that appear in network data.
filtered_authors = authors_df[authors_df['AuthorId'].isin(df_merged.AuthorId)].compute()
len(filtered_authors)
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,
# 18513

# %%
filtered_authors
# Out:
#          AuthorId   Rank     NormalizedName         DisplayName  \
# 4876      2091767  19611        naku virgil         Naku Virgil
# 8387      3859267  19570   joseph b dumyahn   Joseph B. Dumyahn
# 9054      4137389  15940  timothy j biblarz  Timothy J. Biblarz
# 13089     5883335  17417   janet p stamatel   Janet P. Stamatel
# 17478     7991858  19685        wang jinmin        Wang Jin-min
# ...           ...    ...                ...                 ...
# 6874   3186966916  19229      jan m griffin      Jan M. Griffin
# 14190  3186984193  21197  dellinger kristen   Dellinger Kristen
# 21325  3187001419  21197     jan frankowski      Jan Frankowski
# 23120  3187005615  18086     kimberly greer   Kimberly A. Greer
# 49611  3187068690  21197         lee justin          Lee Justin
#
#        LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 4876             1.317635e+09           3                 2              4
# 8387             1.313416e+09           4                 4             25
# 9054             1.174212e+06          20                19           2247
# 13089            1.433027e+08          28                28            343
# 17478            1.332704e+08           4                 4              4
# ...                       ...         ...               ...            ...
# 6874             1.453119e+08           7                 7              4
# 14190                     NaN           1                 1              0
# 21325                     NaN           1                 1              0
# 23120            5.924510e+05           9                 9            224
# 49611                     NaN           1                 1              0
#
#       CreatedDate
# 4876   2016-06-24
# 8387   2016-06-24
# 9054   2016-06-24
# 13089  2016-06-24
# 17478  2016-06-24
# ...           ...
# 6874   2021-08-02
# 14190  2021-08-02
# 21325  2021-08-02
# 23120  2021-08-02
# 49611  2021-08-02
#
# [18513 rows x 9 columns]

# %%
pattern = r'(.+\,)(.+)' # regex for matching the first name and last name
aux_pattern = '(\S+)(.+)' # extra pattern for when the above doesn't match

faculty_df_complete = pd.read_csv("/home/timothyelder/mag/data/faculty_df_complete.csv")
faculty_names = faculty_df_complete['faculty_name'].to_list()

for idx,i in enumerate(faculty_names):
    i = re.sub(r';|:', ',', i)
    # match regex to the file_name string
    if re.search(pattern, i) == None:
        match = re.search(aux_pattern, i)
        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()

        faculty_names[idx] = new_name

    else:
        # match regex to the file_name string
        match = re.search(pattern, i)

        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()
        
        faculty_names[idx] = new_name

faculty_df_complete["faculty_name"] = faculty_names

filtered_authors_2 = authors_df[authors_df['NormalizedName'].isin(faculty_df_complete["faculty_name"])].compute()

filtered_authors_2.head()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,
#       AuthorId   Rank     NormalizedName         DisplayName  \
# 471     184369  15782    charles kurzman     Charles Kurzman
# 736     284723  16745   charles n halaby   Charles N. Halaby
# 1602    633513  16244   karen a hegtvedt   Karen A. Hegtvedt
# 4756   2033759  18047  georgi derluguian   Georgi Derluguian
# 6408   2828213  18740  albert j bergesen  Albert J. Bergesen
#
#       LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 471              114027177.0          79                79           1497
# 736              135310074.0           9                 9           1029
# 1602             150468666.0          48                48           1392
# 4756             111979921.0          16                16             71
# 6408                     NaN          11                11             11
#
#      CreatedDate
# 471   2016-06-24
# 736   2016-06-24
# 1602  2016-06-24
# 4756  2016-06-24
# 6408  2016-06-24

# %%
filtered_authors = filtered_authors.append(filtered_authors_2)
len(filtered_authors)
# Out:
# 357872

# %%
len(set(filtered_authors.NormalizedName))

# %%
filtered_authors = filtered_authors[filtered_authors["LastKnownAffiliationId"].isin(mag_departments.AffiliationId)]
len(filtered_authors)
# Out:
# 11443

# %%
len(set(filtered_authors.NormalizedName))/len(set(faculty_df_complete.faculty_name))
# Out:
# 0.6551983927674535

# %%
filtered_authors[filtered_authors["NormalizedName"].str.contains('raudenbush')]
# Out:
#           AuthorId   Rank         NormalizedName             DisplayName  \
# 389291  2285384011  12637   stephen w raudenbush   Stephen W. Raudenbush
# 304912  2319179191  20843  danielle t raudenbush  Danielle T. Raudenbush
# 626977  2484153218  20238  danielle t raudenbush  Danielle T. Raudenbush
# 705812  2618293213  16989   stephen w raudenbush   Stephen W. Raudenbush
# 768216  2975987558  18688   stephen l raudenbush   Stephen L. Raudenbush
#
#         LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 389291              40347166.0         170               162          50819
# 304912              40347166.0           1                 1              9
# 626977              36258959.0           2                 2             19
# 705812             136199984.0           4                 4            379
# 768216              27837315.0           1                 1             87
#
#        CreatedDate
# 389291  2016-06-24
# 304912  2016-06-24
# 626977  2016-08-23
# 705812  2017-06-05
# 768216  2019-10-03

# %%
authors2papers_df = dd.read_csv(path + 'PaperAuthorAffiliations.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['PaperId', 'AuthorId',
               'AffiliationId', 'AuthorSequenceNumber',
               'OriginalAuthor', 'OriginalAffiliation']

authors2papers_df = authors2papers_df.rename(columns=dict(zip(authors2papers_df.columns, new_columns)))

filtered_authors2papers = authors2papers_df[authors2papers_df['AuthorId'].isin(filtered_authors['AuthorId'])].compute()

# filtered_authors2papers.to_csv('/home/timothyelder/mag/data/authors2papers.csv', index=False)

papers_df = dd.read_csv(path + 'Papers.txt',
                        sep="\t", header=None, dtype={16: 'object', 17: 'object',
                                                      18: 'float64', 19: 'float64',
                                                      20: 'float64', 24: 'object',
                                                       7: 'float64', 9: 'object',
                                                       8: 'string', 14: 'float64'},
                                                       error_bad_lines=False, quoting=csv.QUOTE_NONE,
                                                       encoding='utf-8')

new_columns =['PaperId', 'Rank', 'Doi', 'DocType',
              'PaperTitle', 'OriginalTitle',
              'BookTitle', 'Year', 'Date',
              'OnlineDate', 'Publisher',
              'JournalId', 'ConferenceSeriesId',
              'ConferenceInstanceId', 'Volume',
              'Issue', 'FirstPage', 'LastPage',
              'ReferenceCount', 'CitationCount',
              'EstimatedCitation', 'OriginalVenue',
              'FamilyId', 'FamilyRank', 'DocSubTypes',
              'CreatedDate']

papers_df = papers_df.rename(columns=dict(zip(papers_df.columns, new_columns)))

filtered_papers = papers_df[papers_df['PaperId'].isin(filtered_authors2papers['PaperId'])].compute()

# filtered_papers.to_csv('/home/timothyelder/mag/data/papers.csv', index=False)

# %%
filtered_papers
