# %% [markdown]
# # Linking Affiliation with Network Data
#
# In this notebook I want to start linking the universities/departments that appear in the network dataset to their affiliation ID that appears in the MAG dataset. There are few enough universities that where there are not exact matches on the basis of the name of the school, that I can do a little bit of work to manually find the appropriate ID.
#
# But first, I will try to make it easy for myself and normalize the university name and do a one to one match on the normalized name, see what proportion of schools I have and the proceed from there.
#
# Ultimately, this will be helpful because we will do a direct link from the network dataset and the MAG dataset by matching the authors name (direct matches only) and their most recent affiliation. Hopefully that will get us a more accurate look at the citations and publication counts for everyone.

# %%
import os
import re
import csv
import glob
import json
import pandas as pd
import dask.dataframe as dd

os.chdir('/home/timothyelder/mag')

path = '/project/jevans/MAG_0802_2021_snap_shot/'

# read in the normalized faculty names from the network data
with open("data/faculty_names.txt", "r") as f:
    faculty_names = json.loads(f.read())

faculty_df_complete = pd.read_csv('data/faculty_df_complete.csv')
faculty_df_complete = faculty_df_complete[faculty_df_complete["year_observed"] >= 2020] # subset to just 2020-21 observations

departments = set(faculty_df_complete['current_dept'].to_list())
departments = list(departments)

# %% [markdown]
# ## Normalizing Department Names

# %%
for idx, i in enumerate(departments):
    i = i.lower()
    i = re.sub(',|\.', '', i)
    i = re.sub('-', ' ', i)
    i = re.sub('\'', ' ', i)
    i = re.sub('\&', ' ', i)
    
    i = i.strip()
    departments[idx] = i
    
len(set(departments))
# Out:
# 164

# %% [markdown]
# ### Load MAG Affiliations and direct match

# %%
affiliations_df = dd.read_csv(path + 'Affiliations.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['AffiliationId', 'Rank', 'NormalizedName', 'DisplayName',
               'GridId', 'OfficialPage', 'WikiPage', 'PaperCount', 
               'PaperFamilyCount', 'CitationCount', 'Iso3166Code', 'Latitude', 
               'Longitude', 'CreatedDate']

affiliations_df = affiliations_df.rename(columns=dict(zip(affiliations_df.columns, new_columns)))

mag_departments = affiliations_df[affiliations_df['NormalizedName'].isin(set(departments))].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:737: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   **kwargs,
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,

# %%
len(mag_departments)/len(departments) # 80% is not too shabby
# Out:
# 0.9390243902439024

# %%
mag_departments
# Out:
#        AffiliationId  Rank                              NormalizedName  \
# 711        114395901  7179              university of nebraska lincoln
# 714        121847817  9794                    the graduate center cuny
# 917        110378019  8472     southern illinois university carbondale
# 928        157725225  5687  university of illinois at urbana champaign
# 1116       149910238  8372                       kent state university
# ...              ...   ...                                         ...
# 26393       51556381  6339                      university of virginia
# 26540      204250578  6285             university of california irvine
# 26882      859038795  6982                               virginia tech
# 26961      133999245  8748              university of nevada las vegas
# 26962      150468666  6301                            emory university
#
#                                       DisplayName         GridId  \
# 711                University of Nebraska–Lincoln  grid.24434.35
# 714                     The Graduate Center, CUNY  grid.253482.a
# 917       Southern Illinois University Carbondale  grid.263856.c
# 928    University of Illinois at Urbana–Champaign  grid.35403.31
# 1116                        Kent State University  grid.258518.3
# ...                                           ...            ...
# 26393                      University of Virginia  grid.27755.32
# 26540            University of California, Irvine  grid.266093.8
# 26882                               Virginia Tech  grid.438526.e
# 26961             University of Nevada, Las Vegas  grid.272362.0
# 26962                            Emory University  grid.189967.8
#
#                    OfficialPage  \
# 711         http://www.unl.edu/
# 714     http://www.gc.cuny.edu/
# 917         http://www.siu.edu/
# 928    http://www.illinois.edu/
# 1116       http://www.kent.edu/
# ...                         ...
# 26393  http://www.virginia.edu/
# 26540       http://www.uci.edu/
# 26882        http://www.vt.edu/
# 26961      http://www.unlv.edu/
# 26962     http://www.emory.edu/
#
#                                                 WikiPage  PaperCount  \
# 711    http://en.wikipedia.org/wiki/University_of_Neb...       66965
# 714    http://en.wikipedia.org/wiki/Graduate_Center,_...        6964
# 917    http://en.wikipedia.org/wiki/Southern_Illinois...       27118
# 928    http://en.wikipedia.org/wiki/University_of_Ill...      239875
# 1116   http://en.wikipedia.org/wiki/Kent_State_Univer...       27178
# ...                                                  ...         ...
# 26393  http://en.wikipedia.org/wiki/University_of_Vir...      123661
# 26540  http://en.wikipedia.org/wiki/University_of_Cal...      119519
# 26882         http://en.wikipedia.org/wiki/Virginia_Tech       98500
# 26961  http://en.wikipedia.org/wiki/University_of_Nev...       22857
# 26962      http://en.wikipedia.org/wiki/Emory_University      133222
#
#        PaperFamilyCount  CitationCount Iso3166Code   Latitude   Longitude  \
# 711               65385        1739822          US  40.817500  -96.701390
# 714                6619         131006          US  40.748330  -73.983330
# 917               26721         542894          US  37.710426  -89.219310
# 928              229505        8303046          US  40.110540  -88.228410
# 1116              26568         564292          US  41.146410  -81.341740
# ...                 ...            ...         ...        ...         ...
# 26393            118683        4308646          US  38.035000  -78.505000
# 26540            114212        4551837          US  33.645350 -117.842644
# 26882             95119        2335341          US  37.225000  -80.425000
# 26961             22033         416889          US  36.107790 -115.143761
# 26962            130452        5045195          US  33.791110  -84.323330
#
#       CreatedDate
# 711    2016-06-24
# 714    2016-06-24
# 917    2016-06-24
# 928    2016-06-24
# 1116   2016-06-24
# ...           ...
# 26393  2016-06-24
# 26540  2016-06-24
# 26882  2016-06-24
# 26961  2016-06-24
# 26962  2016-06-24
#
# [154 rows x 14 columns]

# %% [markdown]
# Lets check which departments did not get matched

# %%
#mag_departments.NormalizedName.to_list()

# %%
no_match = []
for dept in departments:
    if dept not in mag_departments.NormalizedName.to_list():
        no_match.append(dept)
print(len(no_match))
print(set(no_match))
# Out:
# 11
# {'oklahoma state university', 'university of texas dallas', 'university of north carolina greensboro', 'university of north carolina chapel hill', 'university of illinois chicago', 'university of texas el paso', 'university of maryland', 'city university of new york queens college', 'state university of new york buffalo', 'state university of new york albany', 'university of alabama birmingham'}

# %% [markdown]
# ### Manually Finding the no matched departments

# %%
affiliations_df[affiliations_df['NormalizedName'].str.contains('of maryland')].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,
#        AffiliationId   Rank  \
# 2623        66946132   6016
# 4483       342796859  10713
# 5167        14285509  11426
# 7481        79272384   8210
# 10077      130076704  13242
# 10621      118784327   9863
# 10781      281892367  16412
# 11687      126744593   6988
# 13283      149521062   9893
# 16216     1317227900  12428
# 16708       22407884  11668
# 17719     1315496137  10030
# 23148       97061514  11814
# 23559      103114056  11113
# 24102       15881279  12927
# 24346       78874557  11961
#
#                                           NormalizedName  \
# 2623                 university of maryland college park
# 4483   university of maryland college of agriculture ...
# 5167               university of maryland medical system
# 7481             university of maryland baltimore county
# 10077  university of maryland college of information ...
# 10621     university of maryland biotechnology institute
# 10781                       allegany college of maryland
# 11687                   university of maryland baltimore
# 13283  university of maryland center for environmenta...
# 16216                      university system of maryland
# 16708               university of maryland eastern shore
# 17719              university of maryland medical center
# 23148          university of maryland university college
# 23559  university of maryland marlene and stewart gre...
# 24102                  notre dame of maryland university
# 24346                      st mary s college of maryland
#
#                                              DisplayName         GridId  \
# 2623                University of Maryland, College Park            NaN
# 4483   University of Maryland College of Agriculture ...            NaN
# 5167               University of Maryland Medical System  grid.413038.d
# 7481            University of Maryland, Baltimore County  grid.266673.0
# 10077  University of Maryland College of Information ...            NaN
# 10621     University of Maryland Biotechnology Institute            NaN
# 10781                       Allegany College of Maryland  grid.422304.3
# 11687                  University of Maryland, Baltimore  grid.411024.2
# 13283  University of Maryland Center for Environmenta...  grid.291951.7
# 16216                      University System of Maryland  grid.410443.6
# 16708               University of Maryland Eastern Shore  grid.266678.b
# 17719              University of Maryland Medical Center  grid.413036.3
# 23148          University of Maryland University College  grid.470043.4
# 23559  University of Maryland Marlene and Stewart Gre...            NaN
# 24102                  Notre Dame of Maryland University  grid.421318.d
# 24346                     St. Mary's College of Maryland  grid.422521.2
#
#                     OfficialPage  \
# 2623         http://www.umd.edu/
# 4483    http://www.agnr.umd.edu/
# 5167        http://www.umms.org/
# 7481        http://www.umbc.edu/
# 10077    http://ischool.umd.edu/
# 10621                        NaN
# 10781   http://www.allegany.edu/
# 11687  http://www.umaryland.edu/
# 13283      http://www.umces.edu/
# 16216       http://www.usmd.edu/
# 16708       http://www.umes.edu/
# 17719        http://www.umm.edu/
# 23148       http://www.umuc.edu/
# 23559                        NaN
# 24102        http://www.ndm.edu/
# 24346       http://www.smcm.edu/
#
#                                                 WikiPage  PaperCount  \
# 2623   http://en.wikipedia.org/wiki/University_of_Mar...      162499
# 4483   http://en.wikipedia.org/wiki/University_of_Mar...        4030
# 5167   http://en.wikipedia.org/wiki/University_of_Mar...        1027
# 7481   http://en.wikipedia.org/wiki/University_of_Mar...       21975
# 10077  http://en.wikipedia.org/wiki/University_of_Mar...         211
# 10621  http://en.wikipedia.org/wiki/University_of_Mar...        2580
# 10781  http://en.wikipedia.org/wiki/Allegany_College_...          13
# 11687  http://en.wikipedia.org/wiki/University_of_Mar...       68720
# 13283  http://en.wikipedia.org/wiki/University_of_Mar...        3622
# 16216  http://en.wikipedia.org/wiki/University_System...         288
# 16708  http://en.wikipedia.org/wiki/University_of_Mar...        1517
# 17719  http://en.wikipedia.org/wiki/University_of_Mar...        5076
# 23148  http://en.wikipedia.org/wiki/University_of_Mar...        1165
# 23559  http://en.wikipedia.org/wiki/University_of_Mar...        1447
# 24102  http://en.wikipedia.org/wiki/Notre_Dame_of_Mar...         433
# 24346  http://en.wikipedia.org/wiki/St._Mary's_Colleg...        1009
#
#        PaperFamilyCount  CitationCount Iso3166Code   Latitude  Longitude  \
# 2623             152936        5835216          US  38.988060 -76.944720
# 4483               4024          56708          US  38.991670 -76.940830
# 5167               1024          25854          US  39.287000 -76.618920
# 7481              20878         654937          US  39.255500 -76.711260
# 10077               206           5109          US  38.988167 -76.941500
# 10621              2554         149621          US  39.286390 -76.605830
# 10781                12            167          US  39.652780 -78.729170
# 11687             68074        2545913          US  39.291390 -76.625000
# 13283              3596         165487          US  39.043503 -76.130060
# 16216               286          12064          US  39.002403 -76.953354
# 16708              1485          18563          US  38.212000 -75.685000
# 17719              5062          92435          US  39.288300 -76.623600
# 23148              1152          17472          US  38.985813 -76.956700
# 23559              1435          42395          US  39.288310 -76.623640
# 24102               432           4507          US  39.352000 -76.622000
# 24346               983          15739          US  38.186660 -76.430940
#
#       CreatedDate
# 2623   2016-06-24
# 4483   2016-06-24
# 5167   2016-06-24
# 7481   2016-06-24
# 10077  2016-06-24
# 10621  2016-06-24
# 10781  2016-06-24
# 11687  2016-06-24
# 13283  2016-06-24
# 16216  2016-06-24
# 16708  2016-06-24
# 17719  2016-06-24
# 23148  2016-06-24
# 23559  2016-06-24
# 24102  2016-06-24
# 24346  2016-06-24

# %% [markdown]
# # Merging Dataframes and Matching with MAG to get Authors

# %%
pattern = r'(.+\,)(.+)' # regex for matching the first name and last name
aux_pattern = '(\S+)(.+)' # extra pattern for when the above doesn't match

faculty_df_complete = pd.read_csv("/home/timothyelder/mag/data/faculty_df_complete.csv")
faculty_names = faculty_df_complete['faculty_name'].to_list()

for idx,i in enumerate(faculty_names):
    i = re.sub(r';|:', ',', i)
    # match regex to the file_name string
    if re.search(pattern, i) == None:
        match = re.search(aux_pattern, i)
        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()

        faculty_names[idx] = new_name

    else:
        # match regex to the file_name string
        match = re.search(pattern, i)

        new_name = match.group(2) + ' ' + match.group(1)
        new_name = re.sub('\/', 'l', new_name, count=1) # replaces / for l, a common error
        new_name = re.sub('\,', '', new_name, count=1)
        new_name = re.sub('\.', '', new_name, count=1)
        new_name = re.sub('\‘', '', new_name, count=1)
        new_name = new_name.lower()
        new_name = new_name.strip()
        
        faculty_names[idx] = new_name

faculty_df_complete["faculty_name"] = faculty_names

# %%
faculty_df_complete = faculty_df_complete.rename(columns={"current_dept": "NormalizedName"})

# %%
departments = faculty_df_complete.NormalizedName.to_list()
for idx, i in enumerate(departments):
    i = i.lower()
    i = re.sub(',|\.', '', i)
    i = re.sub('-', ' ', i)
    i = i.strip()
    departments[idx] = i
    
faculty_df_complete["NormalizedName"] = departments

# %%
new_df = faculty_df_complete.merge(mag_departments, how='left', on="NormalizedName")

# %%
# Load authors dataframe from MAG
authors_df = dd.read_csv(path + 'Authors.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['AuthorId', 'Rank',
               'NormalizedName', 'DisplayName',
               'LastKnownAffiliationId', 'PaperCount',
               'PaperFamilyCount', 'CitationCount', 'CreatedDate']

authors_df = authors_df.rename(columns=dict(zip(authors_df.columns, new_columns)))
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:737: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   **kwargs,

# %%
# Filter authors dataframe for authors that appear in network data.
filtered_authors = authors_df[authors_df['NormalizedName'].isin(new_df.faculty_name)].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,

# %%
newest_df = filtered_authors[filtered_authors["LastKnownAffiliationId"].isin(mag_departments.AffiliationId)]

# %%
newest_df[newest_df["NormalizedName"].str.contains('abbott')]
# Out:
#           AuthorId   Rank    NormalizedName        DisplayName  \
# 648530  1989828844  16774  abbott l ferriss  Abbott L. Ferriss
# 317765  2099401717  21172     andrew abbott      Andrew Abbott
# 578287  2154730292  13605     andrew abbott      Andrew Abbott
# 769114  2315731772  19751  abbott l ferriss  Abbott L. Ferriss
# 184441  2496683362  19868     andrew abbott      Andrew Abbott
# 596960  2688264622  19159     walter abbott      Walter Abbott
# 222385  2761731307  19438     andrew abbott      Andrew Abbott
# 710468  3021416277  17187  abbott l ferriss  Abbott L. Ferriss
# 660675  3027886861  20060     andrew abbott      Andrew Abbott
#
#         LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 648530             150468666.0          26                26            547
# 317765              32971472.0           1                 1              1
# 578287              40347166.0         118               117          12854
# 769114             200719446.0           4                 4              1
# 184441             170201317.0           1                 1             95
# 596960              99041443.0           1                 1             52
# 222385             136199984.0           1                 1             32
# 710468              84218800.0           7                 6            533
# 660675              33213144.0           3                 3              3
#
#        CreatedDate
# 648530  2016-06-24
# 317765  2016-06-24
# 578287  2016-06-24
# 769114  2016-06-24
# 184441  2016-08-23
# 596960  2017-06-30
# 222385  2017-10-20
# 710468  2020-05-13
# 660675  2020-05-29

# %%
len(set(newest_df.NormalizedName.to_list()))/len(set(faculty_df_complete.faculty_name.to_list()))
# Out:
# 0.4775238573581115

# %%
newest_df
# Out:
#           AuthorId   Rank      NormalizedName         DisplayName  \
# 736         284723  16745    charles n halaby   Charles N. Halaby
# 1602        633513  16244    karen a hegtvedt   Karen A. Hegtvedt
# 4756       2033759  18047   georgi derluguian   Georgi Derluguian
# 15293      6937523  18139      sharon koppman      Sharon Koppman
# 16702      7643552  18154  gordana rabrenovic  Gordana Rabrenovic
# ...            ...    ...                 ...                 ...
# 821058  3186645146  19175    jukka savolainen    Jukka Savolainen
# 833894  3186675539  20486     jenifer bratter     Jenifer Bratter
# 855224  3186726551  20463          geoff ward          Geoff Ward
# 909291  3186854906  18517        omer r galle       Omer R. Galle
# 927882  3186899265  20504         victor chen         Victor Chen
#
#         LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 736                135310074.0           9                 9           1029
# 1602               150468666.0          48                48           1392
# 4756               111979921.0          16                16             71
# 15293              204250578.0          17                17             92
# 16702               12912129.0          12                12            113
# ...                        ...         ...               ...            ...
# 821058             185443292.0           7                 7             14
# 833894             143302722.0           2                 2              1
# 855224              12912129.0           2                 2              2
# 909291             200719446.0           4                 4             59
# 927882             921990950.0           2                 2              0
#
#        CreatedDate
# 736     2016-06-24
# 1602    2016-06-24
# 4756    2016-06-24
# 15293   2016-06-24
# 16702   2016-06-24
# ...            ...
# 821058  2021-08-02
# 833894  2021-08-02
# 855224  2021-08-02
# 909291  2021-08-02
# 927882  2021-08-02
#
# [9474 rows x 9 columns]

# %%
newest_df
# Out:
#           AuthorId   Rank      NormalizedName         DisplayName  \
# 471         184369  15782     charles kurzman     Charles Kurzman
# 736         284723  16745    charles n halaby   Charles N. Halaby
# 1602        633513  16244    karen a hegtvedt   Karen A. Hegtvedt
# 4756       2033759  18047   georgi derluguian   Georgi Derluguian
# 10277      4636371  20723  barbara trepagnier  Barbara Trepagnier
# ...            ...    ...                 ...                 ...
# 833894  3186675539  20486     jenifer bratter     Jenifer Bratter
# 844940  3186701852  21197           wei zhang           Wei Zhang
# 855224  3186726551  20463          geoff ward          Geoff Ward
# 909291  3186854906  18517        omer r galle       Omer R. Galle
# 927882  3186899265  20504         victor chen         Victor Chen
#
#         LastKnownAffiliationId  PaperCount  PaperFamilyCount  CitationCount  \
# 471               1.140272e+08          79                79           1497
# 736               1.353101e+08           9                 9           1029
# 1602              1.504687e+08          48                48           1392
# 4756              1.119799e+08          16                16             71
# 10277             1.545704e+08           1                 1             12
# ...                        ...         ...               ...            ...
# 833894            1.433027e+08           2                 2              1
# 844940            1.331385e+09           1                 1              0
# 855224            1.291213e+07           2                 2              2
# 909291            2.007194e+08           4                 4             59
# 927882            9.219910e+08           2                 2              0
#
#        CreatedDate
# 471     2016-06-24
# 736     2016-06-24
# 1602    2016-06-24
# 4756    2016-06-24
# 10277   2016-06-24
# ...            ...
# 833894  2021-08-02
# 844940  2021-08-02
# 855224  2021-08-02
# 909291  2021-08-02
# 927882  2021-08-02
#
# [10503 rows x 9 columns]

# %%
mag_departments[mag_departments["AffiliationId"] == 32971472]
# Out:
#       AffiliationId  Rank   NormalizedName      DisplayName         GridId  \
# 8104       32971472  5515  yale university  Yale University  grid.47100.32
#
#               OfficialPage                                      WikiPage  \
# 8104  http://www.yale.edu/  http://en.wikipedia.org/wiki/Yale_University
#
#       PaperCount  PaperFamilyCount  CitationCount Iso3166Code  Latitude  \
# 8104      236418            227650       10778674          US  41.31111
#
#       Longitude CreatedDate
# 8104  -72.92667  2016-06-24

# %%
    










authors2papers_df = dd.read_csv(path + 'PaperAuthorAffiliations.txt',
                                           sep="\t", header=None,
                                           error_bad_lines=False,
                                           quoting=csv.QUOTE_NONE,
                                           encoding='utf-8')

new_columns = ['PaperId', 'AuthorId',
               'AffiliationId', 'AuthorSequenceNumber',
               'OriginalAuthor', 'OriginalAffiliation']

authors2papers_df = authors2papers_df.rename(columns=dict(zip(authors2papers_df.columns, new_columns)))

filtered_authors2papers = authors2papers_df[authors2papers_df['AuthorId'].isin(df_filtered['AuthorId'])].compute()

filtered_authors2papers.to_csv('/home/timothyelder/mag/data/authors2papers.csv', index=False)

papers_df = dd.read_csv(path + 'Papers.txt',
                        sep="\t", header=None, dtype={16: 'object', 17: 'object',
                                                      18: 'float64', 19: 'float64',
                                                      20: 'float64', 24: 'object',
                                                       7: 'float64', 9: 'object',
                                                       8: 'string', 14: 'float64'},
                                                       error_bad_lines=False, quoting=csv.QUOTE_NONE,
                                                       encoding='utf-8')

new_columns =['PaperId', 'Rank', 'Doi', 'DocType',
              'PaperTitle', 'OriginalTitle',
              'BookTitle', 'Year', 'Date',
              'OnlineDate', 'Publisher',
              'JournalId', 'ConferenceSeriesId',
              'ConferenceInstanceId', 'Volume',
              'Issue', 'FirstPage', 'LastPage',
              'ReferenceCount', 'CitationCount',
              'EstimatedCitation', 'OriginalVenue',
              'FamilyId', 'FamilyRank', 'DocSubTypes',
              'CreatedDate']

papers_df = papers_df.rename(columns=dict(zip(papers_df.columns, new_columns)))

filtered_papers = papers_df[papers_df['PaperId'].isin(filtered_authors2papers['PaperId'])].compute()

filtered_papers.to_csv('/home/timothyelder/mag/data/papers.csv', index=False)

print("Script complete...")

# %% [markdown]
# # Loading the Fuzzy Matches Dataframes

# %%
# concatenating individual matched dataframes
match_path = r'/home/timothyelder/matches'
all_files = glob.glob(match_path + "/*.csv")
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files) # generate a list of files to concatenate

df_merged = pd.concat(df_from_each_file, ignore_index=True) # Concatenate pandas dataframes
df_merged.head()

# Saving Merged dataframe
#df_merged.to_csv("/home/timothyelder/mag/data/authors.csv", index=False)
# Out:
#    Unnamed: 0  best_match_score __id_left     __id_right  \
# 0           0          0.060897    0_left  1617022_right
# 1          22          0.038916    1_left   629022_right
# 2          27          0.181168    2_left   147719_right
# 3          77          0.440146    3_left  1550995_right
# 4          78          0.330313    4_left  1309911_right
#
#              faculty_name           network_name      AuthorId  \
# 0      Siegenthaler, Jurg      jurg siegenthaler  3.049211e+09
# 1          Clark, Leon E.          leon e. clark  3.044426e+09
# 2  Young, Gloria (Gay) A.  gloria (gay) a. young  3.042337e+09
# 3          Stone, Russell          russell stone  3.048906e+09
# 4     Dickerson, Bette J.     bette j. dickerson  3.047763e+09
#
#     NormalizedName
# 0    jurg bernhard
# 1      l e de leon
# 2        a c young
# 3  russell e stone
# 4      j dickerson

# %%
df_merged.best_match_score.mean()
# Out:
# 0.15449487617496827

# %%
df_merged.best_match_score.std()
# Out:
# 0.16013018783726413

# %%
df_merged.best_match_score.min()
# Out:
# -1.8427614920506716

# %%
df_merged.best_match_score.max()
# Out:
# 1.3052927282296176

# %%
df_merged.best_match_score.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df_merged = df_merged[df_merged['best_match_score'] >= .50]
df_merged.head()
# Out:
#      Unnamed: 0  best_match_score __id_left     __id_right  \
# 65         2990          0.659706   74_left  1571423_right
# 79         3556          0.586469   89_left  1365075_right
# 112        4876          0.622506  125_left   850412_right
# 140        6029          0.553071  155_left   126077_right
# 199        8864          0.553071  216_left   126077_right
#
#             faculty_name        network_name      AuthorId  \
# 65   Blankenship, Kim M.  kim m. blankenship  3.048999e+09
# 79    Kronenfeld, Jennie   jennie kronenfeld  3.048038e+09
# 112    Petts, Richard J.    richard j. petts  3.045549e+09
# 140      Jang, Sung Joon      sung joon jang  3.042249e+09
# 199      Jang, Sung Joon      sung joon jang  3.042249e+09
#
#                NormalizedName
# 65          kim m blankenship
# 79   jennie jacobs kronenfeld
# 112           richard j betts
# 140             jang sung jin
# 199             jang sung jin

# %%
# Filter authors dataframe for authors that appear in network data.
filtered_authors = authors_df[authors_df['AuthorId'].isin(df_merged.AuthorId)].compute()
# Out:
# /home/timothyelder/.conda/envs/soc_of_soc/lib/python3.7/site-packages/dask/dataframe/io/csv.py:134: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   path_info,

# %%
newest_df = filtered_authors[filtered_authors["LastKnownAffiliationId"].isin(mag_departments.AffiliationId)]

# %%
len(set(newest_df.NormalizedName))/len(set(faculty_df_complete.faculty_name))
# Out:
# 0.36049723756906077
